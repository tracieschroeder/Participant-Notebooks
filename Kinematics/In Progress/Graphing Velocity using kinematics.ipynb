# %% [markdown]
# # Velocity Graph Matching
# In this activity, you'll use the *velocity function* to model different types of motion.
#
# To get started,
# - You won't hurt anything by experimenting. If you break it, close the tab and open the activity again to start over.
# - Use our driver navigator model to complete, you are working as a pair
# - One person will need the **PhyPhox** app for a later part
# - Answer every question, and share with me through ecampus,
#
# When you're ready, run each code cell until you get down to **Part One**.

# %%
# this cell only needs to be run once, but re-exectuing it doesn't hurt anything either
# imports software packages (not too exciting)
import pandas as pd
import numpy as np
# %matplotlib inline
import matplotlib as mpl
import matplotlib.pyplot as plt

# %%
# this sets the coefficients
vi = 0
a = .5
print("initial velocity =", vi, "[some units]")
print("acceleration =", a, "[some units]")
# Out:
# initial velocity = 0 [some units]
# acceleration = 0.5 [some units]

# %% [markdown]
# ## Part One
# The code above sets values for some parameters of motion.
#
# These coefficients can be used to predict the motion using the *velocity function*. It's a linear equation that predicts the velocity of an object:
# $$v_f=v_i +at$$
# The variables are:
# - final velocity, $v_f$
# - initial velocity, $v_i$
# - acceleration, $a$
# - time, $t$
#
#
# For the code below, remember the '#' means it is a comment. here are some things you should indentify
# - The variables and equation listed above, in the block of code
# - At what timee does the data start and stop?
# - the labels for each axis, and a title for the graph need to change
# - include the units for variables on each axis

# %%
# makes an empty position/time data set
time_list = []
velocity_list = []
t = 0               # sets a starting value for time

while (t < 11):                  # runs the 4 lines below until time is not < 11
    time_list.append(t)          # saves the time value
    vf = vi + a*t                # calculates vf
    velocity_list.append(vf)     # saves vf as the position value
    t = t + 1                    # increases the time value for the next loop

#   this creates a scatterplot: plt.scatter(x-variable, y-variable)
plt.scatter(time_list, velocity_list)
plt.title("this could use a better title")
plt.xlabel("labels are important")
plt.ylabel("I'm lonely");

# %%
#@markdown What did you change in part one? did we adjust the physics or the coding?

Answer = '' #@param {type: 'string'}

# %% [markdown]
# ## Part Two
# The code above makes a graph of a *velocity function*.
# - How does the shape of the graph indicate the object is accelerating?
# - Edit the coefficients in the **next 3 graphs** at the top of the code box to model the different types of motion below. You'll need to run the graph code to see the new graph.
#     - Model constant speed motion at 5 m/s.
#     - Model the motion of an object moving backwards.
#     - Model an object slowing down.

# %%
# this sets the coefficients
vi = 5  #change these variables to get the correct graph
a = 0
print("initial velocity =", vi, "[some units]")
print("acceleration =", a, "[some units]")

# makes an empty position/time data set
time_list = []
velocity_list = []
t = 0               # sets a starting value for time

while (t < 11):                  # runs the 4 lines below until time is not < 11
    time_list.append(t)          # saves the time value
    vf = vi + a*t                # calculates vf
    velocity_list.append(vf)     # saves vf as the position value
    t = t + 1                    # increases the time value for the next loop

#   this creates a scatterplot: plt.scatter(x-variable, y-variable)
plt.scatter(time_list, velocity_list)
plt.title("Constant Speed at 5m/s")
plt.xlabel("labels are important")
plt.ylabel("I'm lonely");
# Out:
# initial velocity = 5 [some units]
# acceleration = 0 [some units]

# %%
# this sets the coefficients
vi =0
a = 0
print("initial velocity =", vi, "[some units]")
print("acceleration =", a, "[some units]")

# makes an empty position/time data set
time_list = []
velocity_list = []
t = 0               # sets a starting value for time

while (t < 11):                  # runs the 4 lines below until time is not < 11
    time_list.append(t)          # saves the time value
    vf = -(vi + a*t)                # calculates vf
    velocity_list.append(vf)     # saves vf as the position value
    t = t + 1                    # increases the time value for the next loop

#   this creates a scatterplot: plt.scatter(x-variable, y-variable)
plt.scatter(time_list, velocity_list)
plt.title("My object is now moving backwards")
plt.xlabel("labels are important")
plt.ylabel("I'm lonely");
# Out:
# initial velocity = 0 [some units]
# acceleration = 0 [some units]

# %%
# this sets the coefficients
vi = 0
a = 0
print("initial velocity =", vi, "[some units]")
print("acceleration =", a, "[some units]")

# makes an empty position/time data set
time_list = []
velocity_list = []
t = 0               # sets a starting value for time

while (t < 11):                  # runs the 4 lines below until time is not < 11
    time_list.append(t)          # saves the time value
    vf = vi + a*t                # calculates vf
    velocity_list.append(vf)     # saves vf as the position value
    t = t + 1                    # increases the time value for the next loop

#   this creates a scatterplot: plt.scatter(x-variable, y-variable)
plt.scatter(time_list, velocity_list)
plt.title("My object is slowing down")
plt.xlabel("labels are important")
plt.ylabel("I'm lonely");
# Out:
# initial velocity = 10 [some units]
# acceleration = -0.5 [some units]

# %%
#@markdown Throughtout part one what were some things in the blocks of code that changed?

Answer = '' #@param {type: 'string'}

# %%
#@markdown Why does one graph have a slope of 0?

Answer = '' #@param {type: 'string'}

# %%
#@markdown What would graph #2 look like if we changed the x-axis to represent the position instead of velocity?

Answer = '' #@param {type: 'string'}

# %% [markdown]
# ## Part 3: Using our own data!
# these instruciton will tell you how to collect your data
# - Use someones phone that has the PhyPhox app
# - Select the "Acceleration (without g)" mode
# - When you hit play, it will start collecting data
# - Stand a few feet apart and toss the phone to your partner, then they will toss it back
# - Hit stop once the original person receives the phone again
#
#
# ## importing data to this worksheet
# Now we will need to export our data.
# - In PhyPhox hit the three dots at the top, and "export data" then export to excel.
# - Send the file to whoever is logged into the computer through their email
# now these instructions tell you how to get your data on the worksheet
# - On your computer, open your email and download the file
# - open with google sheets and select **file > Share > Publish to Web**
# - Copy the link and past in the code box below in place of the current link

# %%
data = pd.read_csv('https://docs.google.com/spreadsheets/d/e/2PACX-1vQ-FR3nX6oDdyHofC0wtdzOGXRISwcNwJsoIxPnMVX0quA40kNLMyGX3jdlXHe9C_N-qLVl12QaNlCi/pub?output=csv')

data.head(4)
# Out:
#       Time (s)  Linear Acceleration x (m/s^2)  Linear Acceleration y (m/s^2)  \
# 0  0.011062345                       0.000000                       0.000000
# 1  0.015911772                       0.027265                      -0.040065
# 2  0.020762293                       0.012206                      -0.033623
# 3   0.02561198                       0.070252                      -0.012984
#
#    Linear Acceleration z (m/s^2)  Absolute acceleration (m/s^2)
# 0                       0.000000                       0.000000
# 1                       0.021204                       0.052898
# 2                       0.041850                       0.055054
# 3                       0.053240                       0.089098

# %%
plt.hist(data['Linear Acceleration x (m/s^2)'], bins=100, range=[-5,5], log=False)  # makes the histogram
plt.title("Good enough Title")
plt.xlabel("x-axis label (in GeV/c^2)")
plt.ylabel("number of events")
plt.grid(False);

# %%
#@markdown Why do you think the graph above would show so many data points having an acceleration of 0?

Answer = '' #@param {type: 'string'}

# %%
plt.hist(data['Linear Acceleration z (m/s^2)'], bins=20, range=[5,10], log=False)  # makes the histogram
plt.title("How often did the sensor measure z acceleration")
plt.xlabel("Acceleration in the z-axis (up and down)")
plt.ylabel("number of events")
plt.grid(False);

# %%
#@markdown Using the histogram above, estimate what the acceleration of your phone going up and down must be.

Answer = '' #@param {type: 'string'}

# %% [markdown]
# ## Analyzing our data
# Discuss some of these questions with your partner, use the data you got
# - Why would there be a so many values that are close to 0.0 m/s^2 for the x direction?
# - Why would we graph the z direction to find acceleration due to gravity?
#  - What mumber did you get for the accerlation of your phone going up and down?
# - What are some factors that could create errors in your data?
# - What are some ways we can work to eliminate those factors?

# %% [markdown]
# ---
# ## Saving Your Work
# This is running on a Google server on a distant planet and deletes what you've done when you close this tab. To save your work for later use or analysis you have a few options:
# - File > "Save a copy in Drive" will save it to you Google Drive in a folder called "Collaboratory". You can run it later from there.
# - File > "Download .ipynb" to save to your computer (and run with Jupyter software later)
# - File > Print to ... um ... print.
# - To save an image of a graph or chart, right-click on it and select Save Image as ...
#
#
# **follow any of the above options and upload your work into your ecampus accout under the "Velocity graphs using kinematics" assignment**
#
#
#
#
#
#
#
#
#
# ## Credits
# This notebook was designed by [Adam LaMee](https://adamlamee.github.io/), who coordinated its development as the [PhysTEC](https://www.phystec.org/) Teacher-in-residence in the [University of Central Florida's Physics department](https://sciences.ucf.edu/physics/). Thanks to the great folks at [Binder](https://mybinder.org/) and [Google Colaboratory](https://colab.research.google.com/notebooks/intro.ipynb) for making this notebook interactive without you needing to download it or install [Jupyter](https://jupyter.org/) on your own device. Find more activities and license info at [CODINGinK12.org](http://www.codingink12.org).
