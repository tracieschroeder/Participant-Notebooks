# %% [markdown]
# # Making an HR Diagram with Globular Cluster 47 Tucanae
# This is where an introduction will go...

# %% [markdown]
# #Part 1: Getting the data

# %%
# Import modules that contain functions we need
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
# Read in the star data
# data = pd.read_csv('https://github.com/jhickeytx/HR-Diagram-Lab/raw/main/47_Tuc_WISE_Data%20(1).csv')
data2 = pd.read_csv('https://github.com/jhickeytx/HR-Diagram-Lab/raw/main/47_Tuc_WISE_Data%20(1).csv')

data.head() # this shows the first few lines of the data
# Out:
#            designation        ra        dec  w1mpro  w2mpro  w3mpro  w4mpro
# 0  J002418.89-720226.0  6.078738 -72.040563  10.492  11.194  11.642   9.014
# 1  J002411.64-720325.4  6.048524 -72.057071   7.746   7.922   7.938   8.555
# 2  J002431.06-720542.9  6.129427 -72.095261  10.320  10.970  11.480   9.157
# 3  J002413.34-720354.7  6.055595 -72.065214   8.324   8.498   8.490   8.114
# 4  J002337.17-720502.4  5.904906 -72.084023   9.669  10.051  10.410   9.090

# %%
# This shows the "shape" of the data (# of rows, # of columns)
data.shape
# Out:
# (154, 7)

# %% [markdown]
# # Sky Plot of the Cluster

# %%
plt.scatter(data['ra'],data['dec'])
plt.xlim(0,359)
plt.ylim(-90,90)
plt.title("Sky Plot")
plt.xlabel("RA")
plt.ylabel("Dec");

# %% [markdown]
# # Making the "HR Diagram"
# We are actually going to use a color magnitude diagram of the cluster to simulate a graph of Lum. vs Temp.

# %%
# This makes a plot of all the stars' postions on the sky

plt.scatter(data['w4mpro']-data['w1mpro'],data['w1mpro'])
plt.ylim(max(data['w1mpro']),min(data['w1mpro']))
plt.xlim(max(data['w4mpro']-data['w1mpro']),min(data['w4mpro']-data['w1mpro']))
plt.title('Color Magnitude Diagram')
plt.xlabel('W4-W1')
plt.ylabel('W1')
# Out:
# Text(0, 0.5, 'W1')

# %% [markdown]
# # Determining the cluster age
# moving on to the next part of the thing...

# %% [markdown]
# # Main Sequence Turnoff
