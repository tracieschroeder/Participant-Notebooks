# %% [markdown]
# The Vostok Ice Core tells us a great deal about CO2 concentration in the atmosphere over many thousands of years.

# %% [markdown]
# $\huge Atmospheric CO2 Levels$ <BR>
# The first portion of the problem set is developed around data from the Russian Vostok Station in East Antarctica. Samples of atmospheric gasses were taken from increasing depths within the ice, and the mean age of the samples were taken as well as CO2 concentration. The second data set is a composite of ice core data and (since 1958) direct measurement of the atmosphere from the Mauna Loa Observatory in Hawai'i. These data are more current than those from the Vostok Ice Core. The data are recorded below.
#
# Your assignment is to develop scatter graphs that relate age of ice as a function of depth, and CO2 concentration as a function of the mean age of the air. The data represents time as yr BP, or years before the present time. Make your graph represent those years extend from 450000 years ago until the present time. Develop some type of analytical statement concerning these sample sets.
#
#
# Here is some information about this data as well as ice core sampling: http://cdiac.ornl.gov/trends/co2/vostok.html and https://en.wikipedia.org/wiki/Ice_core#Vostok

# %%
# Imports
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import matplotlib as mpl

#Source of data
data = pd.read_csv("https://raw.githubusercontent.com/dannydaniel7/4-leptons/master/Vostok.csv")

data.head(5)
# Out:
#                    Mean    Age  Depth  CO2ppm
# 0                 149.1   5679   2342   284.7
# 1                 173.1   6828   3634   272.8
# 2                 177.4   7043   3833   268.1
# 3                 228.6   9523   6220   262.2
# 4                 250.3  10579   7327   254.6

# %%
data.shape
# Out:
# (363, 4)

# %%
plt.plot(data['Age'],data['CO2ppm'],linestyle='-', marker='o', color='b', markersize=2)
plt.xlabel('Age (Before Present)')
plt.ylabel('CO2 ppm')
plt.title('Vostok Ice Core Reading')
plt.grid(True)
#plt.axis([23000, 1000, 1E-6, 500000000])
plt.show()

# %% [markdown]
# There is a set of data for the past decades from the Mauna Loa Observatory. Produce a graph of the CO2 levels as shown by the data, and reflect upon the results.

# %%
# Write code to examine these data...https://raw.githubusercontent.com/dannydaniel7/4-leptons/master/Mauna%20Loa.csv

data = pd.read_csv("https://raw.githubusercontent.com/dannydaniel7/4-leptons/master/Mauna%20Loa.csv")

data.head(5)
# Out:
#    year    mean   unc
# 0  1959  315.97  0.12
# 1  1960  316.91  0.12
# 2  1961  317.64  0.12
# 3  1962  318.45  0.12
# 4  1963  318.99  0.12

# %%
plt.plot(data['year'],data['mean'],linestyle='-', marker='o', color='b', markersize=2)
plt.xlabel('Year')
plt.ylabel('CO2 ppm')
plt.title('Mauna Loa Monthy CO2 (Keeling Curve)')
plt.grid(True)
#plt.axis([23000, 1000, 1E-6, 500000000])
plt.show()
# Data: NOAA Global Monitoring Laboratory https://www.esrl.noaa.gov/gmd/ccgg/trends/data.html

# %%
# Explain both graphs and compare them.

# %%
data = pd.read_csv("https://raw.githubusercontent.com/dannydaniel7/4-leptons/master/Mauna%20Loa.csv")

data.head(5)
# Out:
#    year    mean   unc
# 0  1959  315.97  0.12
# 1  1960  316.91  0.12
# 2  1961  317.64  0.12
# 3  1962  318.45  0.12
# 4  1963  318.99  0.12

# %%
plt.plot(data['year'],data['mean'],linestyle='-', marker='o', color='b', markersize=2)
plt.xlabel('Year')
plt.ylabel('CO2 ppm')
plt.title('Mauna Loa Yearly CO2 (Keeling Curve)')
plt.grid(True)
#plt.axis([23000, 1000, 1E-6, 500000000])
plt.show()

# %%
data = pd.read_csv("https://raw.githubusercontent.com/dannydaniel7/4-leptons/master/monthly%20data.csv")

data.head(5)
#data.columns
# Out:
#    year  month  dec_year     co2  co2ave  marker
# 0  1958      3  1958.208  315.71  314.62      -1
# 1  1958      4  1958.292  317.45  315.29      -1
# 2  1958      5  1958.375  317.50  314.71      -1
# 3  1958      6  1958.458  317.10  314.85      -1
# 4  1958      7  1958.542  315.86  314.98      -1

# %%
plt.plot(data['dec_year'],data['co2'],linestyle='-', marker='o', color='b', markersize=2)
plt.xlabel('Year')
plt.ylabel('CO2 ppm')
plt.title('Mauna Loa Monthy CO2 (Keeling Curve)')
plt.grid(True)
#plt.axis([23000, 1000, 1E-6, 500000000])
plt.show()

# %%
data = pd.read_csv("https://raw.githubusercontent.com/dannydaniel7/4-leptons/master/1850-now.csv")

data.head(5)
# Out:
#      year    CO2
# 0  1850.0  285.2
# 1  1851.0  285.1
# 2  1852.0  285.0
# 3  1853.0  285.0
# 4  1854.0  284.9

# %%
plt.plot(data['year'],data['CO2'],linestyle='-', marker='o', color='b', markersize=2)
plt.xlabel('Year')
plt.ylabel('CO2 ppm')
plt.title('Recent CO2 Data')
plt.grid(True)
#plt.figure(figsize=(6,6))
plt.show()

# %%
plt.plot(data['year'],data['CO2'],linestyle='-', marker='o', color='b', markersize=2)
plt.xlabel('Year')
plt.ylabel('CO2 ppm')
plt.title('Mauna Loa Monthy CO2 (Keeling Curve)')
plt.grid(True)
plt.xlim(2000, 2005)
plt.ylim(360,390)
#plt.figure(figsize=(6,6))
plt.show()

# %%
plt.plot(data['year'],data['CO2'],linestyle='-', marker='o', color='b', markersize=2)
plt.xlabel('Year')
plt.ylabel('CO2 ppm')
plt.title('Mauna Loa Monthy CO2 (Keeling Curve)')
plt.grid(True)
plt.xlim(2000, 2020)
plt.ylim(360,390)
#plt.figure(figsize=(6,6))
plt.show()
