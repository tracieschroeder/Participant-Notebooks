# %% [markdown]
# # Unit 1: Constant Motion
# >Measuring Distance & Displacement
# >>Converting lengths in SI Units
#
#
# SI unit for length: meters (m)
#
# SI prefixes & value
# >kilo (k): 1000 or 10^3
#
# >centi (c): .01 or 10^-2
#
# #Success Criteria
# >I can explain meaning/purpose/use of the SI prefixes?
#
# >I can develop process for converting between SI lengths by identifying pattern in conversions
#
# >I can adjust code to convert using other prefixes

# %% [markdown]
# #Part 1: Understanding SI conversions & prefixes
# You will be having this notebook convert values that you enter. You will use these conversions to develop rules for converting that you can use to to convert values yourself.
#
# 1.   Press play below.
# 2.   Follow prompts to convert 5 different values (of your choosing) for each available conversion.
# 3.   Record these conversions on your worksheet.

# %%
#interactions with students
conversions_available = [(1,'km','m'),
                         (2,'m','km'),
                         (3,'cm','m'),
                         (4,'m','cm')
                         ]
print('conversions_available:')
print()

for conversion_number, from_unit, to_unit in conversions_available:
  print(f'{conversion_number}) {from_unit} -> {to_unit}')
print()
conversion = input('Enter the number of the conversion to use -->')
conversion_index = int(conversion) - 1

conversion_number, from_unit, to_unit = conversions_available[conversion_index]
print()
from_value = float(input(f'Enter {from_unit} -->'))
print()

#logic for conversions
if conversion_number == 1:
    to_value = from_value * 1000
    print(f'{from_value} {from_unit} -> {to_value} {to_unit}')
if conversion_number == 2:
    to_value = from_value / 1000
    print(f'{from_value} {from_unit} -> {to_value} {to_unit}')
if conversion_number == 3:
    to_value = from_value / 100
    print(f'{from_value} {from_unit} -> {to_value} {to_unit}')
if conversion_number == 4:
    to_value = from_value * 100
    print(f'{from_value} {from_unit} -> {to_value} {to_unit}')
# Out:
# conversions_available:
#
# 1) km -> m
# 2) m -> km
# 3) cm -> m
# 4) m -> cm
#
# Enter the number of the conversion to use -->3
#
# Enter cm -->8
#
# 8.0 cm -> 0.08 m

# %% [markdown]
# Questions to answer on student sheet:
#
#
#
# 1.   What pattern do you notice for the values when converting from meters (m) to kilometers (km)
# 2.   List item

# %% [markdown]
# #Part 2: Modifying the code
#
# Google search "SI prefixes". Find 2 - 3 prefixes other than kilo & centi. You are going to edit my code so that it can now also convert using these additional prefixes.
#
#
# Task 1: Below is the code we used to do the above conversions. Starting in Line 2, there is a list of conversions defined by this chunk of code. After line 5, add in lines to show the prefixes or possible conversions you will be adding. Note on format: (list number, starting units, ending units)
#
# Task 2: copy the code from lines 22 - 24. These lines of codes tell the program what math to do for each conversion. Change the list number to 6 in Line 22. In line 23, change the conversion factor to match your SI prefix. Repeat this for list number 7 (and 8 if you are doing 3 new prefixes)

# %%
#interactions with students
conversions_available_updated = [(1,'km','m'),
                        (2,'m','km'),
                         (3,'cm','m'),
                         (4,'m','cm')
                         ]
print('conversions_available_updated:')
print()

for conversion_number, from_unit, to_unit in conversions_available_updated:
  print(f'{conversion_number}) {from_unit} -> {to_unit}')
print()
conversion = input('Enter the number of the conversion to use -->')
conversion_index = int(conversion) - 1

conversion_number, from_unit, to_unit = conversions_available_updated[conversion_index]
print()
from_value = float(input(f'Enter {from_unit} -->'))
print()

#logic for conversions
if conversion_number == 1:
    to_value = from_value * 1000
    print(f'{from_value} {from_unit} -> {to_value} {to_unit}')
