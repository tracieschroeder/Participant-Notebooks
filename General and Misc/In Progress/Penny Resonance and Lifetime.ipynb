# %% [markdown]
# <img src="https://upload.wikimedia.org/wikipedia/commons/thumb/8/84/2005-Penny-Uncirculated-Obverse.png/603px-2005-Penny-Uncirculated-Obverse.png" width="300" align="right">
#
# # **The Mass of a Penny . . . Who Cares?**
# Your goals:
# - Learn some Python!
# - Use a histogram to represent penny mass data
# - Interpret the histogram to make claims relating to penny mass
# - Become more familiar with using and understanding box-and-whisker plots, histograms, and scatterplots for representing and analyzing data.
#
# *This is a colab-ified version of an activity shamelessly stolen from the [Quarknet Data Portfolio](https://quarknet.org/data-portfolio/activity/mass-us-pennies)!*

# %% [markdown]
# #**Part 1:** Collecting Data
# - Grab a bunch of pennies.
# - Record the data you collect in [this google sheet](https://docs.google.com/spreadsheets/d/1zlb_XmqUPCY02gtb2ihvSWzkPt7mbzSFN18QIaPNkhM/edit?usp=sharing). Please make sure you select the proper tab so you don't wreck someone else's data!
# - After looking at the google sheet, answer the following questions in the section below:

# %%
Answers=['Student Responses']
i=0
while i<20:
  Answers.append('')
  i+=1
#@markdown 1. Did you notice any patterns as you were recording data? If so, explain. { display-mode: "form" }
Answer1 = ''  #@param {type: "string"}
Answers[1] = Answer1
#@markdown 2. Did you find certain types of data more difficult to record? If so, explain.
Answer2= ''  #@param {type: "string"}
Answers[2]=Answer2
#@markdown 2. What can you tell me by just looking at your data table? (No math or sheet manipulation allowed!) Be sure to justify your claim(s) with evidence.
Answer3 = ''  #@param {type: "string"}
Answers[3]=Answer3

# %% [markdown]
# #**Part 2:** Looking at Data with Python
# Now you will use python to get the class data file and generate a histogram of penny mass.
#
# - Read the comments in green
# - Execute the code cells one at a time by clicking the play button or (ctrl+enter)
# - Messing around with the code can help you understand what is going on!

# %%
# These modules are brought in so we can use the functions in them to do stuff like read data, do math, and graph
import numpy as np
import pandas as pd
import matplotlib as mpl
import matplotlib.pyplot as plt
import random as rand

# I like nice tables!
# %load_ext google.colab.data_table
#%unload_ext google.colab.data_table

# %%
# Load in penny mass file.  I combined the class data into one file and uploaded it to the website for you to retrieve.
data = pd.read_csv('https://raw.githubusercontent.com/jahkobian/CERN-opendata/master/pennymassdata.csv')

# %%
# Take a look at the first 10 rows of the data file
data.head(10)
# Out:
#    mass  year  mint  condition
# 0  2.99  1990     2          2
# 1  3.09  1981     2          1
# 2  3.16  1965     3          1
# 3  2.94  1977     1          2
# 4  3.05  1980     4          2
# 5  3.44  1974     2          2
# 6  2.70  1982     4          1
# 7  2.41  1985     2          2
# 8  3.16  1999     3          1
# 9  2.56  2010     1          1

# %%
# You can choose a column to look at like this
data['mass'].head(15)  # Try changing the header name to see one of the other columns, like 'condition'
# Out:
# 0     2.99
# 1     3.09
# 2     3.16
# 3     2.94
# 4     3.05
# 5     3.44
# 6     2.70
# 7     2.41
# 8     3.16
# 9     2.56
# 10    3.35
# 11    3.32
# 12    2.67
# 13    3.40
# 14    2.56
# Name: mass, dtype: float64

# %%
# Take a look at the statistics of a single column of the data
data['mass'].describe()
# Out:
# count    10000.000000
# mean         2.893671
# std          0.271109
# min          2.110000
# 25%          2.670000
# 50%          2.930000
# 75%          3.100000
# max          3.670000
# Name: mass, dtype: float64

# %%
#@markdown **Based on the statistics . . .**
#@markdown 4. How many pennies did we collect data on?
Answer4 = ''  #@param {type: "string"}
Answers[4]= Answer4
#@markdown 5. Based on the statistics given, what is the mass of a penny?
Answer5 = ''  #@param {type: "string"}
Answers[5]= Answer5
#@markdown 6. What does the rest of that stuff mean?
Answer6 = ''  #@param {type: "string"}
Answers[6]= Answer6

# %%
# Running this block will generate a box-and-whisker plot of the data in the 'mass' column
plt.boxplot(data['mass'], vert=False)
plt.show()

# %%
#@markdown **After generating a box-and-whisker plot . . .**
#@markdown 7. Can you find any correlation(s) between the box-and-whisker plot and the statistics?
Answer7 = ''  #@param {type: "string"}
Answers[7]= Answer7
#@markdown 8. What does a box-and-whisker-plot show?
Answer8 = ''  #@param {type: "string"}
Answers[8]= Answer8
#@markdown 9. What evidence supports your answer to number 8?
Answer9 = ''  #@param {type: "string"}
Answers[9]= Answer9

# %%
# Running this block will generate a histogram of the data in the 'mass' column
plt.figure(figsize=(12,8)) # I like the graph to be big . . .
plt.hist(data['mass'], bins=6, color='firebrick')
plt.show()

# %%
#@markdown **After generating a histogram . . .**
#@markdown 10. Based on what you see, what do you think a histogram shows? (Explain why you think this.)
Answer10 = ''  #@param {type: "string"}
Answers[10]= Answer10
#@markdown 11. What is the range of penny masses represented by this histogram?
#@markdown  - Does this agree with the statistics?
#@markdown  - Does this agree with the box-and-whisker plot?
Answer11 = ''  #@param {type: "string"}
Answers[11]= Answer11
#@markdown 12. What is the most common penny mass in this histogram?
#@markdown  - Does this agree with the statistics?
#@markdown  - Does this agree with the box-and-whisker plot?
Answer12 = ''  #@param {type: "string"}
Answers[12]= Answer12
#@markdown 13. Based on this histogram, what do you think the mass of a penny is and why?
#@markdown  - How does your answer compare to your answer on number 5?
Answer13 = ''  #@param {type: "string"}
Answers[13]= Answer13
#@markdown 14. How would you like the histogram to look different in order to feel more confident about your answer to number 4?
Answer14 = ''  #@param {type: "string"}
Answers[14]= Answer14

# %%
# Running this block will generate a histogram and a box-and-whisker plot of the data in the 'mass' column that are stacked so they sort of line up for comparison
fig, axs = plt.subplots((2), figsize=(12,10))
axs[1].hist(data['mass'], bins=6, color='firebrick')
axs[0].boxplot(data['mass'], vert=False)
plt.show()

# %%
#@markdown **Now that you can see the two plots on top of each other . . .**
#@markdown 15. Are the histogram and box-and-whisker plot related? Do they agree with each other?
#@markdown  - Explain your reasoning.
Answer15 = ''  #@param {type: "string"}
Answers[15]= Answer15
#@markdown 16. What can you see from the box-and-whisker plot that you can't see as obviously on the histogram and vice versa?
Answer16 = ''  #@param {type: "string"}
Answers[16]= Answer16

# %%
# Running this block will generate a histogram of the data in the 'mass' column
plt.figure(figsize=(12,8)) # I like the graph to be big . . .
plt.hist(data['mass'], bins=6, color='firebrick')
plt.show()

# %%
#@markdown **Mess with the bin size in the code above as you answer the following . . . (try 10, 25, 40, 50, etc.)**
#@markdown 17. What is a histogram bin?
Answer17 = ''  #@param {type: "string"}
Answers[17]= Answer17
#@markdown 18. What do you notice as you increase the bin width?
Answer18 = ''  #@param {type: "string"}
Answers[18]= Answer18
#@markdown 19. Has your answer to 'what is the mass of a penny' changed?
#@markdown  - Include evidence and reasoning along with a 'yes' or 'no'
Answer19 = ''  #@param {type: "string"}
Answers[19]= Answer19

# %% [markdown]
# #**Part 3:** Freestyle Data Analysis
# - Based on that last section, you may want to explore possible relationships between mass and other collected data that is available to make more sense of the histogram.
# - Try making histograms of other data columns.
# - How about a scatter plot of two columns that you think may correlate?
# - I have included an example of the syntax for a scatter plot.
# - You can add a new empty code cell by clicking '+ Code' near the top left of the window.

# %%
# histogram some other data
plt.hist(data[''], bins=6) # you may want to adjust the bin size depending on the type of data you are looking at
plt.show()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /usr/local/lib/python3.7/dist-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    3360             try:
# -> 3361                 return self._engine.get_loc(casted_key)
#    3362             except KeyError as err:
#
# /usr/local/lib/python3.7/dist-packages/pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# /usr/local/lib/python3.7/dist-packages/pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: ''
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# ...

# %%
# make a scatter plot, you can decide which columns to use from our data file, x is first and y is second
plt.scatter(data[''],data[''])
plt.show()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /usr/local/lib/python3.7/dist-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    3360             try:
# -> 3361                 return self._engine.get_loc(casted_key)
#    3362             except KeyError as err:
#
# /usr/local/lib/python3.7/dist-packages/pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# /usr/local/lib/python3.7/dist-packages/pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: ''
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# ...

# %%
#@markdown **Your goal is to generate claims about the mass of a penny based on your analysis of the available data.**

#@markdown **This will be your final required task for full credit on this notebook.**

#@markdown **Present your claim(s) with evidence and reasoning below.**
FinalAnswer = ''  #@param {type: "string"}
Answers[20]= FinalAnswer

# %% [markdown]
# #**Part 4:** If You Have Time
#
# Going deeper . . . open if you dare.

# %%
# here is another data file similar to the one you and your class just analyzed
newdata = pd.read_csv('https://raw.githubusercontent.com/jahkobian/CERN-opendata/master/pennymassdatanew.csv')

# %%
# Feel free to copy and recycle code to produce graphs from both datasets.  Take a look at the statistics, box-and-whisker plots, histograms, scatter plots, etc.

# %%
AnswersPlus=['Extension Responses']
i=0
while i<20:
  AnswersPlus.append('')
  i+=1
#@markdown **Use your python knowledge and the code from Part 2 and 3 to thoroughly explore this new dataset and answer the following:**
#@markdown 1. In what way(s) is this dataset similar and/or different from the first one?
Response1 = ''  #@param {type: "string"}
AnswersPlus[1] = Response1
#@markdown 2. What might explain the differences you found?
Response2 = ''  #@param {type: "string"}
AnswersPlus[2] = Response2

# %% [markdown]
# #**Part 4:** Hint
#
# Only after you have given Part 4 a seriously thorough effort!

# %%
# ?
p1 = []
i = 0

while i<10000:
  if rand.random() < 0.35:
    p1.append(round(rand.gauss(2.6,0.15),2))
  else:
    p1.append(round(rand.gauss(3.05,0.17),2))
  i += 1
np.savetxt('afilenamegoeshere.csv',p1, delimiter=',')

# %% [markdown]
# #**Review Your Answers**

# %%
Results = pd.DataFrame(Answers)
Results [1] = AnswersPlus
Results
