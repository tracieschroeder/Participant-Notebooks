# %% [markdown]
# ##**But first, we say hello**
#  Make a copy of this file in your drive. Rename it with the names of your group members.
#
#  The following code was adapted from the *Intro to Coding* activity by Adam Lamee and can be found on codingk12.org along with other awesome activities.

# %%
# Click on this cell. Then click on the play button to the left.
# This "runs" the cell. In other words it tells the computer to carry out the code in the cell.
6+4
# Out:
# 10

# %%
# Anything with a "#" in front of it is just a comment. It isn't read by the computer.
# Try running the previous cell with different numbers and opperations.
#Try this:
(24+6)/5
# Out:
# 6.0

# %%
# The following lines define variables called "a" and "b"
a = 2
b = 3
# The next line shows us what "a" plus "b" is.
a+b
# Out:
# 5

# %%
c=a*b # This line creates another variable, "c".
c # This line tells us what "c" is.

# %%
# This coding language is called "python".
d = "Say Hello" # You just coded in python
d

# %% [markdown]
# ##**Coding Time**
# ## An exploration of relations for Algebra 1 students
#
# In this activity you and your partner will create a scatterplot representing a set of data. You will determine the slope manually and compare it to the computer generated slope of the plot's trendline. You will then create a graph comparing two other sets of data. You will be recording information and thoughts as you go in a seperate document.
#
# One student will have charge over the keyboard at a time. This person is called the Driver. While one person drives the other is the Navigator. The Navigator should read the code and check it, make suggestions, and stay in constant communication with the driver about what is going on. You are a team after all. Partners will switch roles every step.
#
# When your project is completed you will share your screen with the class and explain what assumptions you made and how the outcomes compared to them. Consider how you would go about expanding this data set and what the relation would look like.
#
# You won't hurt anything by experimenting. If you break it, close the tab and open the activity again to start over.
#
# When you're ready, run each code cell by clicking the *play* button.
# Continue until you get down to **Part One**.

# %%
# import some software packages we'll use
import pandas as pd
import numpy as np
import matplotlib as mpl
import matplotlib.pyplot as plt
from statistics import mean

# %%
#import data
data = pd.read_csv('https://vincentarelbundock.github.io/Rdatasets/csv/datasets/cars.csv')
#see credit link in part 1

#Delete the column containing the observation number
del data['Unnamed: 0']

#show the first 3 rows of data (There may be more than 3 rows total. We just want to see the top for now.)
data.head(3)
# Out:
#    speed  dist
# 0      4     2
# 1      4    10
# 2      7     4

# %% [markdown]
# ##**Part 1**
# **This is where you start recording your group's thoughts. Douple Click on this block to add text. Type your thoughts under the questions. Use complete sentences please.**
#
# --------------------------------------------------------
#
# What do you think the column headings might represent?
#
# *Fun fact: you have to double space, or the code shows up on the same line.*
#
# Use the following code to determine how many data points you have. Is that a sufficient number of points to draw a conclusion? Why?

# %%
#show the number of rowns and columns in the data set
data.shape
# Out:
# (50, 2)

# %% [markdown]
# To answer the next questions find backround information on the data [here.](https://vincentarelbundock.github.io/Rdatasets/doc/datasets/cars.html)
#
# What do the columns represent?
#
# What are their units?
#
# When was this data gathered?
#
# How might this data look different if the same observations were made today? Why?

# %% [markdown]
# ##**Part 2**
# Determine the average speed and stopping distance in this data set. The code to find the average speed is written for you. You must write the code to determine the average stopping distance. Include units.

# %%
#Find the average speed
AvgSpeed=np.mean(data['speed'])
print("Average Speed =", AvgSpeed, "mph")

#Find the average stopping distance
#Put code here
# Out:
# Average Speed = 15.4 mph

# %% [markdown]
# ##**Part 3**
# Generate a scatterplot of your data.
#
# Write the headings for the dependent and indepedent variable in. Title and label the axis of your scatterplot. Include units. Feel free to change the color of your scatterplot.
#
# Once you have generated your scatterplot run the code until you get to **part 4**. This will generate your trendline.

# %%
#Create a scatterplot
x=data['column name for your x variable']
y=data['column name for your y variable']
plt.scatter(x, y, color='purple')
plt.title('name me')
plt.xlabel('me too')
plt.ylabel('and me')
plt.grid(True)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /usr/local/lib/python3.6/dist-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    2645             try:
# -> 2646                 return self._engine.get_loc(key)
#    2647             except KeyError:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'column name for your x variable'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-9-154538e683f9> in <module>()
# ...

# %%
#plot grpah again
x=data['column name for your x variable']
y=data['column name for your y variable']
plt.scatter(x, y, color='purple')
plt.title('name me')
plt.xlabel('me too')
plt.ylabel('and me')
plt.grid(True)

#Generate a trendline
z = np.polyfit(x, y, 1)
p = np.poly1d(z)
plt.plot(x,p(x),"blue")
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /usr/local/lib/python3.6/dist-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    2645             try:
# -> 2646                 return self._engine.get_loc(key)
#    2647             except KeyError:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'column name for your x variable'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-10-67b14524add2> in <module>()
# ...

# %% [markdown]
# Are there any outliers? If so list their coordinates.
#
# What affect do the outliers have on the trendline? Is the trendline a good model? Why?

# %% [markdown]
# ##**Part 4**a
# Next you will determine the slope of the plot by manual calculation.
#
# How do you calculate the slope?
#
# Type the number of lines of data you want to see in the parenthesis in the following code to see your data table so you can identify the coordinates of the points you are going to use. Scroll up to part one if you forgot how many data points you have.
#
# Why did you choose those points?
#
# Once you have your points use the next line of code to complete the slope calculation, and record it. What sign do you expect your slope to have? Why? What does this mean about the data?
#
# What units should the slope have?

# %%
data.head(put a number here) #show however many lines of your data table that you want.
# Out:
#   File "<ipython-input-11-37d657876ba4>", line 1
#     data.head(put a number here) #show however many lines of your data table that you want.
#                   ^
# SyntaxError: invalid syntax

# %%
slope = (do math here) #calculate slope by hand
print(slope,'put units here')
# Out:
#   File "<ipython-input-12-d2593d814e98>", line 1
#     slope = (do math here) #calculate slope by hand
#                    ^
# SyntaxError: invalid syntax

# %% [markdown]
# ##**Part 4**b
# Run the next block of code to calculate the slope of the trendline. How does it compare with your calculated slope? What may have caused differences? Do you need to make adjustments to your calculation?

# %%
#Compute the actual slope of the trendline
def best_fit_slope(x,y):
    m = (((mean(x)*mean(y)) - mean(x*y)) /
         ((mean(x)**2) - mean(x**2)))
    return m

m = best_fit_slope(x,y)
print(m,'put units here')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-13-3a55625425c1> in <module>()
#       5     return m
#       6
# ----> 7 m = best_fit_slope(x,y)
#       8 print(m,'put units here')
#
# NameError: name 'x' is not defined

# %% [markdown]
# How many digits should your slope have? Use the code below to round your slope.

# %%
#round to some number of digits
print(round(m,put a number here),'put units here')
# Out:
#   File "<ipython-input-14-34aed1617aa8>", line 2
#     print(round(m,put a number here),'put units here')
#                       ^
# SyntaxError: invalid syntax

# %% [markdown]
# ##**Part 5**
# That trendline seems a little off. What should stopping disance be when you are moving 0 mph? Lets make a trendline that better suits the data. Adjust the y intercept and slope accordingly.
#
# What slope and y intercept did you choose? Why did you use those?
#
# How does the slope of your new trendline compare with that of your old trendline?
#
# Are their outliers? What might have caused these?
#
# Remeber to look over the [background info](https://vincentarelbundock.github.io/Rdatasets/doc/datasets/cars.html). What do we know? What do we not know?

# %%
#plot grpah again
x=data['column name for your x variable']
y=data['column name for your y variable']
plt.scatter(x, y, color='purple')
plt.title('name me')
plt.xlabel('me too')
plt.ylabel('and me')
plt.grid(True)

#create a better trendline
x2 = np.linspace(0,27,50)
m2 = put a slope here
b = put a y intercept here
y2 = (m2*x2)+b #What is this equation called? Look familiar?
plt.plot(x2,y2, "choose a color")
# Out:
#   File "<ipython-input-15-27e2a26af708>", line 12
#     m2 = put a slope here
#              ^
# SyntaxError: invalid syntax

# %% [markdown]
# ##**Part 6**
#
# Now it's your turn!
#
# Using the code you have been given, create a scatterplot with a trendline for another set of data from [this database](https://vincentarelbundock.github.io/Rdatasets/datasets.html). Start by importing the csv file by right clicking on csv and choosing copy link address then pasting into your code.
#
# Be prepared to present your code to your class and explain your findings. Your classmates will have the opportunity to ask questions and make suggestions.

# %%
# Write code here.

# %% [markdown]
# **Saving Your Work**
#
# This is running on a Google server on a distant planet and deletes what you've done when you close this tab. To save your work for later use or analysis you have a few options:
#
# File > "Save a copy in Drive" will save it to you Google Drive in a folder called "Collaboratory". You can run it later from there.
# File > "Download .ipynb" to save to your computer (and run with Jupyter software later)
# File > Print to ... um ... print.
# Save an image to your computer of a graph or chart, right-click on it and select Save Image as ...
#
# **Credits**
# This notebook was designed with the assistance of Adam LaMee and other Quarknet teachers and fellows. Thanks to the great folks at Binder and Google Colaboratory for making this notebook interactive without you needing to download it or install Jupyter on your own device.
